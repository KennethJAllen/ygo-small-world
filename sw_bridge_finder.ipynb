# %% [markdown]
# # Import Functions

# %%
from sw_functions import sub_df, load_main_monsters, create_sw_adjacency_matrix, ydk_to_monster_names

# %% [markdown]
# # Load Cards and Create Adjacency Matrix

# %%
MAIN_MONSTERS = load_main_monsters()
SW_ADJACENCY_MATRIX = create_sw_adjacency_matrix(MAIN_MONSTERS) #small world adjacency matrix of all cards

# %% [markdown]
# # Find Best Bridges Function

# %%
def find_best_bridges(deck_monster_names, required_target_names):
    #inputs: list of monster names and list of monsters that are required to connect with the small world bridges
    #output: The bridges that connect the most cards in your deck and connect with all the required targets
    deck_monster_names = list(set(deck_monster_names) | set(required_target_names)) #union names
    deck_indices = sub_df(MAIN_MONSTERS, deck_monster_names, 'name').index #indices of deck monsters
    required_indices = sub_df(MAIN_MONSTERS, required_target_names, 'name').index #indices of required targets

    num_required_targets = len(required_target_names) #number of cards required to connect with one bridge

    required_monster_matrix = SW_ADJACENCY_MATRIX[required_indices,:] #array corresponding to (required connection monsters) by (all monsters)
    num_bridges_to_required_cards = required_monster_matrix.sum(axis=0) #number of required connections satisfied by all monsters
    required_bridge_mask = num_bridges_to_required_cards==num_required_targets
    df_bridges = MAIN_MONSTERS[required_bridge_mask].copy() #data frame of monsters connecting all required targets
    required_bridge_indices = df_bridges.index #indices of monsters that satisfy all required connections
    if len(df_bridges)==0:
        print('There are no monsters that bridge all required targets.')
        return

    #subset of adjacency matrix corresponding to (deck monsters) by (monsters with connections to the required cards)
    bridge_matrix = SW_ADJACENCY_MATRIX[deck_indices,:][:,required_bridge_indices]

    num_deck_bridges = bridge_matrix.sum(axis=0)
    df_bridges['number_of_connections'] = num_deck_bridges
    df_bridges = df_bridges[df_bridges['number_of_connections'] > 0]
    df_bridges = df_bridges[['number_of_connections', 'name', 'type', 'attribute', 'level', 'atk', 'def']] #reorder columns
    df_bridges = df_bridges.sort_values(by=['number_of_connections','name'], ascending=[False, True]).reset_index(drop=True) #reorder rows
    return df_bridges

# %% [markdown]
# # Examples

# %% [markdown]
# ### List of Names

# %%
#cards that we want to find bridges between
deck_monster_names = ['Ash Blossom & Joyous Spring',
                        'Effect Veiler',
                        'Ghost Belle & Haunted Mansion',
                        'Mathmech Addition',
                        'Mathmech Circular',
                        'Mathmech Diameter',
                        'Mathmech Multiplication',
                        'Mathmech Nabla',
                        'Mathmech Sigma',
                        'Mathmech Subtraction',
                        'Parallel eXceed',
                        'Maxx "C"']

#cards that are required to connect with a bridge
required_target_names = ['Mathmech Circular',
                        'Maxx "C"',
                        'Parallel eXceed']

bridges = find_best_bridges(deck_monster_names, required_target_names)
bridges.head(20)
# Out:
#     number_of_connections                                 name         type  \
# 0                    10.0    Boot-Up Corporal - Command Dynamo      Machine
# 1                    10.0       Boot-Up Soldier - Dread Dynamo      Machine
# 2                    10.0                     Doshin @Ignister      Cyberse
# 3                    10.0                           Flowerdino     Dinosaur
# 4                    10.0                           Gem-Turtle         Rock
# 5                    10.0                         Gogogo Giant         Rock
# 6                    10.0      Heroic Challenger - Swordshield      Warrior
# 7                    10.0           Knightmare Corruptor Iblee      Cyberse
# 8                    10.0                 Madolche Marmalmaide  Spellcaster
# 9                    10.0                 Miracle Jurassic Egg     Dinosaur
# 10                   10.0                              Protron      Cyberse
# 11                   10.0                         Shell Knight         Rock
# 12                   10.0      Superheavy Samurai Blue Brawler      Machine
# 13                   10.0                      Token Collector        Fiend
# 14                   10.0               Witch Doctor of Sparta  Spellcaster
# 15                   10.0                Wynn the Wind Charmer  Spellcaster
# 16                   10.0                 ZW - Ultimate Shield         Aqua
# 17                   10.0                              Zombino       Zombie
# 18                    9.0                          Armored Bee       Insect
# 19                    9.0  Battlewasp - Arbalest the Rapidfire       Insect
#
#    attribute  level     atk     def
# 0      EARTH    4.0     0.0  2000.0
# 1      EARTH    4.0     0.0  2000.0
# 2      EARTH    1.0   100.0   800.0
# 3      EARTH    4.0  2000.0     0.0
# 4      EARTH    4.0     0.0  2000.0
# 5      EARTH    4.0  2000.0     0.0
# 6      EARTH    4.0     0.0  2000.0
# 7       DARK    2.0     0.0     0.0
# 8      EARTH    4.0   800.0  2000.0
# 9      EARTH    4.0     0.0  2000.0
# 10     EARTH    1.0   100.0   100.0
# 11     EARTH    4.0     0.0  2000.0
# 12     EARTH    4.0     0.0  2000.0
# 13     EARTH    4.0     0.0  2000.0
# 14     EARTH    4.0   400.0  2000.0
# 15      WIND    3.0   500.0  1500.0
# 16     EARTH    4.0     0.0  2000.0
# 17     EARTH    4.0  2000.0     0.0
# 18      WIND    4.0  1600.0  1200.0
# 19      WIND    4.0  1800.0   800.0

# %% [markdown]
# ### From YDK File

# %%
ydk_file = 'mathmech_deck.ydk'
mathmech_monster_names = ydk_to_monster_names(ydk_file, MAIN_MONSTERS)
mathmech_required_target_names = []
bridges_mathmech = find_best_bridges(mathmech_monster_names, mathmech_required_target_names)
bridges_mathmech.head(20)
# Out:
#     number_of_connections                             name          type  \
# 0                    12.0                    Guard Penguin  Winged Beast
# 1                    11.0  Adamancipator Crystal - Dragite          Rock
# 2                    11.0  Adamancipator Crystal - Raptite          Rock
# 3                    11.0        Alchemist of Black Spells   Spellcaster
# 4                    11.0                       Backlinker       Cyberse
# 5                    11.0           Gendo the Ascetic Monk   Spellcaster
# 6                    11.0                         Mixeroid       Machine
# 7                    11.0         Performapal Stamp Turtle          Aqua
# 8                    11.0                   Shinobird Crow  Winged Beast
# 9                    11.0                   Super Crashbug         Fiend
# 10                   11.0                Yosenju Shinchu L          Rock
# 11                   11.0                Yosenju Shinchu R          Rock
# 12                   10.0                      Alien Skull       Reptile
# 13                   10.0           Anarchist Monk Ranshin   Spellcaster
# 14                   10.0                          Aratama         Fiend
# 15                   10.0             Archfiend Eccentrick         Fiend
# 16                   10.0                   Armored Cybern       Machine
# 17                   10.0          Blue Mountain Butterspy       Warrior
# 18                   10.0              Capricious Darklord         Fairy
# 19                   10.0                          D/D Ark         Fiend
#
#    attribute  level     atk     def
# 0      WATER    4.0     0.0  1200.0
# 1      WATER    4.0     0.0  2200.0
# 2       WIND    4.0     0.0  2200.0
# 3       WIND    4.0  1200.0  1800.0
# 4       DARK    3.0  1600.0     0.0
# 5      WATER    4.0   300.0  1800.0
# 6       WIND    4.0     0.0  2200.0
# 7      WATER    4.0   100.0  1800.0
# 8       WIND    4.0     0.0     0.0
# 9       DARK    4.0     0.0  3000.0
# 10      WIND    4.0     0.0  2100.0
# 11      WIND    4.0     0.0  2100.0
# 12      WIND    4.0  1600.0  1800.0
# 13     EARTH    4.0  1800.0   100.0
# 14      DARK    4.0   800.0  1800.0
# 15     LIGHT    3.0   800.0  1000.0
# 16      WIND    4.0     0.0  2000.0
# 17      DARK    4.0     0.0  1700.0
# 18      DARK    4.0     0.0  1600.0
# 19      DARK    4.0     0.0  2000.0
