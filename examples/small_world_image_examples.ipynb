# %% [markdown]
# # Import Module

# %%
from ygo_small_world import small_world_functions as sw

# %% [markdown]
# # Generate Images

# %%
ydk_file = 'sample_deck.ydk'

# %%
sw.ydk_to_graph_image(ydk_file)

# %%
sw.ydk_to_matrix_image(ydk_file)

# %%
sw.ydk_to_matrix_image(ydk_file, squared=True)
