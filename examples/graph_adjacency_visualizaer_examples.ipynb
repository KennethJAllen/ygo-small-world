# %% [markdown]
# # Import Module

# %%
from ygo_small_world import graph_adjacency_visualizer as gav

# %% [markdown]
# # Generate Images

# %%
ydk_file = 'sample_deck.ydk'

# %%
gav.ydk_to_graph_image(ydk_file)

# %%
gav.ydk_to_matrix_image(ydk_file)

# %%
gav.ydk_to_matrix_image(ydk_file, squared=True)
